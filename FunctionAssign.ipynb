# %% [markdown]
# Assignment :- Python Function
# ---

# %% [markdown]
# 1. . What is the difference between a function and a method in Python?
# ---
# - Function and method are similar in some kind but major difference is Function is used to return or accept data
# - While , Method is used in OOPs for classes of objects

# %% [markdown]
# 2.  Explain the concept of function arguments and parameters in Python?
# ---
# - Function argument are basically value which we used to assign function workflow . ex - def function(10 , 20)
# - Function Parameters are basically variable which we used for call the function . ex - function(a , b)

# %% [markdown]
# 3.  What are the different ways to define and call a function in Python?
# ---
# - to define function using 'def'
# - to call function by using 'return'
# - to call function by using 'argument' or '*args'

# %% [markdown]
# 4. What are iterators in Python and how do they differ from iterables?
# ---
# - Iterators are basically iter the iterables for function
# - Iterable are basically object which can be iterate

# %% [markdown]
# 5.  Explain the concept of generators in Python and how they are defined.
# ---
# - Generators is a concept in python which use when ever we want run function once in time
# - 'yield' is how we defined generators

# %% [markdown]
# 6. What are the advantages of using generators over regular functions?
# ---
# - Regular function tries to run or execute function in 1 run.
# - So to overcome it , we use Generator to run function statement one by one

# %% [markdown]
# 7. What is a lambda function in Python and when is it typically used?
# ---
# - Lambda function is used to perform mathmatical problem
# - When we use when ever we want some mathmatical condition we use it

# %% [markdown]
# 9. Explain the purpose and usage of the 'map()' function in Python.
# ---
# - map() is a function in python which is used to iterate function which can iterate (List , Tuple)

# %% [markdown]
# 10. What is the difference between 'map()', 'reduce()', and 'filter()' functions in Python?
# ---
# - map() is used to map specified function by iterable
# - reduce() is used to reduce specific function from iteration
# - filter() is used to conditional statement from function in iteration

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using reduce function on this given : list:[47,11,42,13];
# ---
# - ![Loo.jpg](data:image/jpeg;base64,...)
